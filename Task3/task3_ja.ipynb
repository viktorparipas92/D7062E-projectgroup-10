# %% [markdown]
# # D7062E Project
# ## Project Group 10
#
# Contributors:
# - Theo HEMBÄCK
# - PARIPÁS Viktor
# - Jerker ÅBERG
# - Kristofer ÅGREN

# %% [markdown]
# #Task 1

# %% [markdown]
# ## Importing dependencies
# We used the following libraries in the first task:
# - `pandas` to manipulate the data
# - `scikit-learn` for imputing and scaling the data
# - `seaborn` and `matplotlib` for visualization.

# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data exploration
# Let's load the training dataset from the corresponding .csv file.
# Since we know that the columns represent the mean/standard deviation of the positions and angles of the 60 points, respectively, followed by the label name and code, let us rename the columns accordingly to allow for easier reading.

# %%
def load_data():
    training_data = pd.read_csv("train-final.csv", header=None)
    test_data = pd.read_csv("test-final.csv", header=None)

    name_mappings = {
        # Feature columns
        **{i: f"positions_mean_{i}" for i in range(60)},
        **{i: f"positions_std_{i}" for i in range(60, 120)},
        **{i: f"angles_mean_{i}" for i in range(120, 180)},
        **{i: f"angles_std_{i}" for i in range(180, 240)},
        # Label columns
        **{240: "label_name", 241: "label_code"},
    }

    training_data.rename(name_mappings, axis=1, inplace=True)
    training_feature_columns = training_data.columns[:-2]

    training_features = training_data[training_feature_columns]
    training_labels = training_data.label_name
    training_codes = training_data.label_code

    test_data.rename(name_mappings, axis=1, inplace=True)
    test_feature_columns = test_data.columns[:-2]

    test_features = test_data[test_feature_columns]
    test_labels = test_data.label_name

    return (
        training_features,
        training_labels,
        training_codes,
        test_features,
        test_labels,
    )


(
    training_features,
    training_labels,
    training_codes,
    test_features,
    test_labels,
) = load_data()

# %% [markdown]
# Let's show some of the data

# %%
training_features.head()
# Out:
#    positions_mean_0  positions_mean_1  positions_mean_2  positions_mean_3  \
# 0         -0.479730          0.726079          2.403713         -0.481913
# 1          0.051888          0.646871          2.409750          0.060117
# 2         -0.002692          0.624926          2.240212          0.018586
# 3         -0.029336          0.664426          2.443440         -0.023426
# 4          0.065604          0.639172          2.377587          0.069247
#
#    positions_mean_4  positions_mean_5  positions_mean_6  positions_mean_7  \
# 0          0.540689          2.455865         -0.646274          0.406351
# 1          0.451912          2.449198         -0.106647          0.344324
# 2          0.435987          2.269613         -0.152985          0.336314
# 3          0.480809          2.451577         -0.203417          0.353489
# 4          0.447377          2.405972         -0.092707          0.339007
#
#    positions_mean_8  positions_mean_9  ...  angles_std_230  angles_std_231  \
# 0          2.428461         -0.312905  ...        0.403147        0.422235
# 1          2.461468          0.183852  ...        0.458585        0.365385
# 2          2.305371          0.164105  ...        0.556154        0.449078
# 3          2.506273          0.119183  ...        0.458485        0.420331
# 4          2.368022          0.231172  ...        0.498700        0.280299
#
#    angles_std_232  angles_std_233  angles_std_234  angles_std_235  \
# 0        0.730551        0.367526        0.520040        0.493564
# 1        0.428723        0.571661        0.431776        0.279627
# 2        0.537268        0.488480        0.540547        0.542650
# 3        0.713397        0.387092        0.439498        0.417769
# 4        0.671461        0.475014        0.401192        0.372539
#
#    angles_std_236  angles_std_237  angles_std_238  angles_std_239
# 0        0.485049        0.477886        0.607874        0.441320
# 1        0.595978        0.389501        0.241849        0.617291
# 2        0.430114        0.542999        0.454954        0.479623
# 3        0.554555        0.498407        0.565789        0.455313
# 4        0.578720        0.446630        0.580236        0.460550
#
# [5 rows x 240 columns]

# %%
test_features.head()
# Out:
#    positions_mean_0  positions_mean_1  positions_mean_2  positions_mean_3  \
# 0         -0.332255          0.672471          2.450465         -0.323645
# 1         -0.089784          0.656778          2.431880         -0.079363
# 2         -0.427810          0.699557          2.347763         -0.444873
# 3         -0.089790          0.694279          2.428455         -0.072881
# 4         -0.387741          0.540410          2.399926         -0.406310
#
#    positions_mean_4  positions_mean_5  positions_mean_6  positions_mean_7  \
# 0          0.486062          2.526748         -0.483695          0.370296
# 1          0.467939          2.429239         -0.193909          0.349866
# 2          0.530140          2.433568         -0.610365          0.402565
# 3          0.520537          2.496676         -0.255747          0.404209
# 4          0.361768          2.459448         -0.576004          0.262814
#
#    positions_mean_8  positions_mean_9  ...  angles_std_230  angles_std_231  \
# 0          2.534973         -0.172186  ...        0.348333        0.426959
# 1          2.329680          0.081013  ...        0.482754        0.456633
# 2          2.398841         -0.264254  ...        0.582908        0.412314
# 3          2.520148          0.115363  ...        0.409941        0.328799
# 4          2.457772         -0.256852  ...        0.348730        0.311284
#
#    angles_std_232  angles_std_233  angles_std_234  angles_std_235  \
# 0        0.604953        0.464157        0.751404        0.467516
# 1        0.596048        0.461552        0.557319        0.373754
# 2        0.777705        0.318174        0.532617        0.476989
# 3        0.551472        0.498960        0.313094        0.450005
# 4        0.684091        0.457543        0.446787        0.499285
#
#    angles_std_236  angles_std_237  angles_std_238  angles_std_239
# 0        0.306133        0.521694        0.546094        0.439480
# 1        0.515013        0.413323        0.491261        0.530069
# 2        0.487606        0.604556        0.489667        0.433812
# 3        0.581886        0.409794        0.377352        0.578679
# 4        0.512345        0.366741        0.468337        0.526775
#
# [5 rows x 240 columns]

# %% [markdown]
# How many different labels do we have in the training dataset?

# %%
number_of_classes = training_labels.nunique()
number_of_classes
# Out:
# 30

# %% [markdown]
# Now let's take a look at how many occurrences we have of each label.

# %%
training_labels.value_counts().plot(kind="bar", figsize=(10, 4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that `child` is the most common label in the training dataset and that `go` is the least common label.

# %% [markdown]
# Now let's look for columns that have missing values. The missing values are in the following columns (along with the missing value count):

# %%
# Look for columns that have missing values
columns_null_sum = training_features.isnull().sum()
columns_with_nulls = columns_null_sum[columns_null_sum > 0]

print(
    "Total amount of missing values in the dataframe:",
    training_features.isnull().sum().sum(),
)
print("Missing values in the following column indexes (and missing value count):")
print(columns_with_nulls)
# Out:
# Total amount of missing values in the dataframe: 21
# Missing values in the following column indexes (and missing value count):
# positions_mean_7     4
# positions_mean_8     4
# positions_mean_9     4
# positions_mean_14    3
# positions_mean_15    3
# positions_mean_16    3
# dtype: int64

# %% [markdown]
# Some classifiers are more sensitive to the range, mean & outliers of the features, such as linear regression models, for example.
# In order to be able to train a wide range of classifiers and compare them, we will need to preprocess the data for scaling and outlier treatment.

# %% [markdown]
# Let's see if the dataset also contains outliers. There are quite a few way to detect outliers (Source:
# [Outlier detection methods in Scikit-Learn](https://scikit-learn.org/stable/modules/outlier_detection.html)):
# - Isolation forest
# - Local outlier factor
# - One-class support vector machine (SVM)
# - Elliptic envelope
#
# We start by doing a boxplot for all features to get a visual indication of the outlier situation.

# %%
training_features.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a3bbbfa00>], [Text(1, 0, '')])

# %% [markdown]
# Based on the boxplot, there appears to be many columns with outliers. Many classifiers, e.g. linear classifiers like Logistic Regression will not handle outliers well, so we need to find a way to handle also outliers.

# %% [markdown]
# ## Methods

# %% [markdown]
# ### Outliers
#
# As we saw in the boxplot above, there are many columns with outliers. And while there are many methods to detect outliers,let's begin with just identifying the **values** that are farthest from the mean.
#
# A simple approach is to identify the values that lie outside of 3$\sigma$ (that is, three times the standard deviation) as outliers, and drop the rows that have at least one outlier. Let's give it a try.

# %%
# training_features_outliers_marked = training_features[abs(training_features) <= 3]
from scipy import stats

training_features_outliers_marked = training_features[
    np.abs(stats.zscore(training_features.fillna(training_features.mean()))) < 3
]

# %%
training_features_outliers_marked.head()
# Out:
#    positions_mean_0  positions_mean_1  positions_mean_2  positions_mean_3  \
# 0         -0.479730          0.726079          2.403713         -0.481913
# 1          0.051888          0.646871          2.409750          0.060117
# 2         -0.002692          0.624926          2.240212          0.018586
# 3         -0.029336          0.664426          2.443440         -0.023426
# 4          0.065604          0.639172          2.377587          0.069247
#
#    positions_mean_4  positions_mean_5  positions_mean_6  positions_mean_7  \
# 0          0.540689          2.455865         -0.646274          0.406351
# 1          0.451912          2.449198         -0.106647          0.344324
# 2          0.435987          2.269613         -0.152985          0.336314
# 3          0.480809          2.451577         -0.203417          0.353489
# 4          0.447377          2.405972         -0.092707          0.339007
#
#    positions_mean_8  positions_mean_9  ...  angles_std_230  angles_std_231  \
# 0          2.428461         -0.312905  ...        0.403147        0.422235
# 1          2.461468          0.183852  ...        0.458585        0.365385
# 2          2.305371          0.164105  ...        0.556154        0.449078
# 3          2.506273          0.119183  ...        0.458485        0.420331
# 4          2.368022          0.231172  ...        0.498700        0.280299
#
#    angles_std_232  angles_std_233  angles_std_234  angles_std_235  \
# 0        0.730551        0.367526        0.520040        0.493564
# 1        0.428723        0.571661        0.431776        0.279627
# 2        0.537268        0.488480        0.540547        0.542650
# 3        0.713397        0.387092        0.439498        0.417769
# 4        0.671461        0.475014        0.401192        0.372539
#
#    angles_std_236  angles_std_237  angles_std_238  angles_std_239
# 0        0.485049        0.477886        0.607874        0.441320
# 1        0.595978        0.389501        0.241849        0.617291
# 2        0.430114        0.542999        0.454954        0.479623
# 3        0.554555        0.498407        0.565789        0.455313
# 4        0.578720        0.446630        0.580236        0.460550
#
# [5 rows x 240 columns]

# %%
training_features_outliers_removed = training_features_outliers_marked.dropna()
training_features_outliers_removed.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
print("Number of rows left", training_features_outliers_removed.shape[0])
# Out:
# Number of rows left 250

# %% [markdown]
# The boxplot now looks better, except for the second part (columns 60 to 120), which is `positions_std_i`.
# We can also see that if we remove all the rows with at least one detected outlier, we are left with less than half of the original data! This is due to the large number of features.
#
# We need another method for this dataset, let's instead cap the outliers to 3 sigma.

# %%
def pipeline_outliers(df, std_cap=3):
    df = df.copy()

    for column in df.columns:

        mean = df[column].mean(skipna=True)
        std = df[column].std(skipna=True)

        df[column] = np.clip(df[column], -(mean + std_cap * std), mean + std_cap * std)

    return df

# %%
df = pipeline_outliers(training_features)
df.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a4000caf0>], [Text(1, 0, '')])

# %% [markdown]
# ### Missing data

# %% [markdown]
# As we saw above, there are 6 columns that have missing values (3 or 4 missing values each). Many classifiers do not handle missing values directly, such as Logistic Regression and SVM, for example. As such we need to find a way to manage the missing values.

# %% [markdown]
# There are many different ways of handling missing values and we will explore a few of them here. To get started, let's examine the features/columns that contain missing data. The two visualizations chosen for each of the features/columns are:
#
# - *Histogram* - This will give a good indication of the distribution, for example if it appears to be normal.
# - *Boxplot* - We get some additional information from the boxplot showing the median, quartiles as well as outliers.
#
# Let's plot the distributions for the columns with missing data:

# %%
def plot_distributions_for_columns(dataframe, columns):
    # Plot distributions for each of the columns that have missing values
    figure, axes = plt.subplots(2, len(columns), figsize=(12, 6))

    for index, column in enumerate(columns):
        # plot a histogram of the column for the first row
        dataframe[column].plot(kind="hist", ax=axes[0, index], title=column, bins=15)
        # Do a box plot as well
        sns.boxplot(y=dataframe[column], ax=axes[1, index]).set_title(column)

    plt.tight_layout()


plot_distributions_for_columns(training_features, columns_with_nulls.index)

# %% [markdown]
# The distributions are quite different, which mean we may need different imputation techniques for each column.
# For example, the columns `positions_mean_9` and `positions_mean_15` are clearly not normal distributions and replacing missing values with the mean would likely not be ideal.
# For instance in the case of `positions_mean_9` the mean is close to 0 where few other samples are, moreover this feature may even need to be split into two separate features as it appears to be the combination of two gaussian distributions.
#
# Also, we do not know if the missing values themselves have a significance, i.e. we might want to create a separate column to indicate that a missing value is present or not. There are relatively few rows that have missing values, though, that may limit the usefulness of this technique and usefulness will also depend on the classifier used in the end.
#
# For now, we will implement support for the following imputation strategies:
# - Replacing with **mean**
# - **Drop the rows** containing at least one missing value
# - **K-Nearest Neighbour (KNN)** imputation, i.e. use the mean value of the K nearest neighbours

# %%
from sklearn.impute import KNNImputer, SimpleImputer


def impute(dataframe, imputer_class, **kwargs):
    imputer = imputer_class(**kwargs)
    dataframe = dataframe.copy()
    dataframe[dataframe.columns] = imputer.fit_transform(dataframe.values)
    return dataframe


# KNN imputation
def impute_knn(dataframe):
    return impute(dataframe, KNNImputer, n_neighbors=2, weights="uniform")


# Drop rows
def impute_drop_rows(dataframe):
    return dataframe.dropna()


# Mean imputation
def impute_mean(dataframe):
    return impute(dataframe, SimpleImputer, missing_values=np.nan, strategy="mean")

# %% [markdown]
# Let's compare the mean and KNN imputation methods.

# %%
columns_null_sum = training_features.isnull().sum()
columns_with_nulls = columns_null_sum[columns_null_sum > 0]

# %%
# training_features = training_data[training_feature_columns]
all_na_values = training_features.isna()

# %% [markdown]
# First let's execute both imputations individually.
# Starting with the mean imputation, the imputed values are the following:

# %%
training_data_mean_imputed = impute_mean(training_features)
training_data_mean_imputed.values[all_na_values]
# Out:
# array([ 0.33458168,  2.31761983, -0.03841946,  0.33458168,  2.31761983,
#        -0.03841946,  0.33458168,  2.31761983, -0.03841946,  0.33458168,
#         2.31761983, -0.03841946,  2.25511306,  0.08066904,  0.24483198,
#         2.25511306,  0.08066904,  0.24483198,  2.25511306,  0.08066904,
#         0.24483198])

# %% [markdown]
# While the KNN-imputed values look like this:

# %%
training_data_knn_imputed = impute_knn(training_features)
training_data_knn_imputed.values[all_na_values]
# Out:
# array([ 0.34047311,  2.31943747,  0.28644774,  0.3482031 ,  2.39881444,
#        -0.1273677 ,  0.35056898,  2.50631498,  0.39795417,  0.36853525,
#         2.44980983, -0.2093955 ,  2.30348019,  0.1777522 ,  0.21750797,
#         2.05630751,  0.31015251,  0.20072834,  2.31141073,  0.18122421,
#         0.22825797])

# %% [markdown]
# ### Comparison of mean and KNN
# Now it is time to compare the results and visualize the differences on a histogram

# %%
differences = (
    training_data_mean_imputed.values[all_na_values]
    - training_data_knn_imputed.values[all_na_values]
)
plt.hist(differences)
# Out:
# (array([1., 1., 0., 2., 1., 4., 6., 3., 1., 2.]),
#  array([-0.43637363, -0.37285571, -0.30933779, -0.24581987, -0.18230196,
#         -0.11878404, -0.05526612,  0.0082518 ,  0.07176972,  0.13528763,
#          0.19880555]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# We can conclude that the differences between the methods are not significant, the mode is close to zero, for most of the missing values the two methods give very similar imputed values - more than half of the values are in the range [-0.1,0.1]
#
# Now let's look at how the difference is distributed for each column using a boxplot and a swarm plot.

# %%
na_rows, na_columns = np.where(all_na_values)
dataframe_differences_columns = pd.DataFrame(
    {"diff": differences, "column": training_features.columns[na_columns]}
)

fig, axs = plt.subplots(ncols=2)

axis = sns.boxplot(x="column", data=dataframe_differences_columns, y="diff", ax=axs[0])
axis.set_xticklabels(axis.get_xticklabels(), rotation=90)

axis = sns.swarmplot(
    x="column", data=dataframe_differences_columns, y="diff", ax=axs[1]
)
axis.set_xticklabels(axis.get_xticklabels(), rotation=90)

fig.tight_layout()

# %% [markdown]
# When comparing the imputed values between the 'mean' and 'KNN' approaches, we see that they produce very similar values for columns `positions_mean_7` and `positions_mean_16` but larger differences by varying degrees for the other columns. The largest (absolute) deviance is for `positions_mean_9`.
#
#
# Based on this it is likely that we may need to employ different imputation techniques depending on the column/feature.

# %% [markdown]
# For now, however, let's use KNN imputation and make sure that after the imputation there are no more missing values in our dataset. We will bring these three different methods into Task 2 of the project.

# %%
# Let's create a pipeline function that uses the KNN imputation
def pipeline_missing_values(df, method="knn"):
    df = df.copy()

    columns_null_sum = df.isnull().sum()
    columns_with_nulls = columns_null_sum[columns_null_sum > 0]

    if method == "knn":
        df[columns_with_nulls.index] = impute_knn(df[columns_with_nulls.index])
    elif method == "mean":
        df[columns_with_nulls.index] = impute_mean(df[columns_with_nulls.index])
    else:
        raise f"Unknown method {method}"

    assert df.isnull().sum().sum() == 0

    return df

# %% [markdown]
# ### Scaling
# First we will take a look at how the data looks by feature/column. While the dataset contains a lot of features, we can use a boxplot to get an overview understanding of how the different columns compare.

# %% [markdown]
# Let's make a boxplot for every feature to get an overview of how they all relate in terms of range & centre. No need to have labels for the feature names, we just want to show all of them in one plot.

# %%
training_features.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a3f45ec10>], [Text(1, 0, '')])

# %% [markdown]
# The columns are clearly not all scaled to the same range and they have different means. As such a scaler that centers the mean and normalizes (scale to the variance) may be suitable. Let's use scikit's `StandardScaler` for this.
#
# The `StandardScaler`normalizes the data so that the mean becomes zero, and the variance one, i.e. the scaled dataset follows a *standard* normal distribution.

# %%
def pipeline_scale(dataframe):
    scaler = preprocessing.StandardScaler()
    scaled_values = scaler.fit_transform(dataframe.values)
    return pd.DataFrame(scaled_values)


training_features_scaled = pipeline_scale(training_features)
training_features_scaled.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -1.323633  1.421746  0.733025 -1.232600  1.399904  0.822277 -1.422333
# 1  1.003039  0.078953  0.794440  1.093898 -0.102009  0.757567  0.931582
# 2  0.764166 -0.293088 -0.930321  0.915639 -0.371414 -0.985672  0.729450
# 3  0.647555  0.376563  1.137173  0.735317  0.386874  0.780659  0.509463
# 4  1.063069 -0.051572  0.467238  1.133087 -0.178730  0.337967  0.992393
#
#         7         8         9    ...       230       231       232       233  \
# 0  1.259873  0.852019 -1.153361  ... -0.970529  0.275952  1.047194 -1.135466
# 1  0.171022  1.105739  0.933965  ...  0.047047 -0.367940 -1.823802  1.842487
# 2  0.030405 -0.094153  0.850991  ...  1.837917  0.579975 -0.791318  0.629031
# 3  0.331900  1.450155  0.662231  ...  0.045200  0.254384  0.884029 -0.850038
# 4  0.077691  0.387438  1.132799  ...  0.783348 -1.331643  0.485131  0.432586
#
#         234       235       236       237       238       239
# 0  0.769486  0.395003 -0.513685  0.020178  2.181665 -1.544711
# 1 -0.235120 -1.990480  1.426960 -0.876203 -2.053768  1.825020
# 2  1.002887  0.942327 -1.474741  0.680542  0.412169 -0.811236
# 3 -0.147232 -0.450141  0.702284  0.228297  1.694685 -1.276755
# 4 -0.583229 -0.954479  1.125046 -0.296817  1.861857 -1.176475
#
# [5 rows x 240 columns]

# %% [markdown]
# Looks good, i.e. the mean is about 0 and the standard deviation is around 1. All the columns have now been scaled. Let's rerun the boxplot.

# %%
training_features_scaled.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a42f8c610>], [Text(1, 0, '')])

# %% [markdown]
# ## Pipeline

# %% [markdown]
# In the Methods section above we have defined the pipeline methods needed for handling outliers, missing data and scaling. Let's put them all together.

# %%
# Load the data
(
    training_features,
    training_labels,
    training_codes,
    test_features,
    test_labels,
) = load_data()

# Plot before pipeline
training_features.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a45755940>], [Text(1, 0, '')])

# %%
test_features.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a46f59190>], [Text(1, 0, '')])

# %% [markdown]
# Run the pipeline and rerun the boxplot on the resulting dataset

# %%
def run_data_pipeline(features, std_cap=3, impute_method="knn"):
    df = pipeline_outliers(features, std_cap=std_cap)
    df = pipeline_missing_values(df, method=impute_method)
    df = pipeline_scale(df)

    return df


train_df = run_data_pipeline(training_features)
train_df.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a4972f910>], [Text(1, 0, '')])

# %%
test_df = run_data_pipeline(test_features)

test_df.boxplot(figsize=(18, 7))
plt.xticks([1], [""])
# Out:
# ([<matplotlib.axis.XTick at 0x15a4c38ce20>], [Text(1, 0, '')])

# %% [markdown]
# #Task 2

# %% [markdown]
# The following observations have been made of the dataset and affects how models should be trained:
#
# - There are low number, less than 30, of samples per class. As such, overfitting will likely be a problem with more advanced classifiers like decision trees, for example. To address this, we will use a Cross Validation method to evaluate the fit. Furthermore, to ensure we have the same distribution in each fold of the CV, a stratified fold method will be used.
# - The data set is very 'wide' - that is there are a very large amount of features (240) compared to the number of samples (540). To address this, a feature reduction will be used. There are many options for reducing features, such as removing features with strong correlation, low variance or fitting a classifier and removing those features that have low importance. Dimensionality reduction approaches are also common, such as Principal Component Analysis, for example.
# - We will compare RFE to PCA, and select the best performing option.

# %% [markdown]
# ## Feature reduction

# %% [markdown]
# ### RFE
#
# To reduce features, we have selected a Recursive Feature Elimination method using a Support Vector Machine classifier. The reason for selecting a SVM classifier is the combination of speed and the ability to capture non-linearities in the dataset.

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn import svm

train_df = run_data_pipeline(training_features, std_cap=6, impute_method="mean")

from sklearn.linear_model import LogisticRegression


def reduce(n_feats):

    rfe_selector = RFECV(
        estimator=svm.SVC(kernel="linear"),
        cv=StratifiedKFold(n_splits=10),
        min_features_to_select=n_feats,
        step=1,
        n_jobs=4,
    )

    rfe_selector.fit(train_df, training_labels)

    selected_cols = train_df.columns[rfe_selector.get_support()]
    score = np.mean(rfe_selector.cv_results_["mean_test_score"])

    print(n_feats, len(selected_cols), score)

    return selected_cols, score


# Evaluate a few different minimum features to select
rfe_results = [reduce(n) for n in [15, 45]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 67 in <cell line: 31>()
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=26'>27</a>     return selected_cols, score
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=29'>30</a> # Evaluate a few different minimum features to select
# ---> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=30'>31</a> rfe_results = [reduce(n) for n in [15, 45]]
#
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 67 in <listcomp>(.0)
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=26'>27</a>     return selected_cols, score
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=29'>30</a> # Evaluate a few different minimum features to select
# ---> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=30'>31</a> rfe_results = [reduce(n) for n in [15, 45]]
#
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 67 in reduce(n_feats)
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=19'>20</a> rfe_selector.fit(train_df, training_labels)
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=21'>22</a> selected_cols = train_df.columns[rfe_selector.get_support()]
# ---> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=22'>23</a> score = np.mean(rfe_selector.cv_results_["mean_test_score"])
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=24'>25</a> print(n_feats, len(selected_cols), score)
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y123sZmlsZQ%3D%3D?line=26'>27</a> return selected_cols, score
#
# AttributeError: 'RFECV' object has no attribute 'cv_results_'

# %% [markdown]
# As seen above, the cross validated performance peaks at 40 selected features, at around an accuracy of 0.851.

# %% [markdown]
# ### PCA
#
# Let's also look at how PCA would perform, also evaluating it using the same SVM classifiers as in the RFE case and same amount of CV folds (10). Code below is based on sklearn example at https://scikit-learn.org/stable/auto_examples/compose/plot_digits_pipe.html

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pca = PCA()

pipe = Pipeline(steps=[("pca", pca), ("svm", svm.SVC(kernel="linear"))])
param_grid = {"pca__n_components": np.arange(10, 100, 5)}
search = GridSearchCV(pipe, param_grid, cv=10, n_jobs=4)
search.fit(train_df, training_labels)

print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.804):
# {'pca__n_components': 85}

# %% [markdown]
# Using PCA, we achieve the highest accuracy of 0.804 on the same cross validated classifiers as RFE above using 85 PCA components.

# %% [markdown]
# ### Conclusion
#
# The RFE approach gives us higher accuracy with fewer features than PCA, so we will select the RFE approach instead.

# %%
rfe_best_ix = np.argmin([score for _, score in rfe_results])
rfe_columns, _ = rfe_results[rfe_best_ix]

train_reduced_df = train_df[train_df.columns[rfe_columns]]
test_reduced_df = test_df[test_df.columns[rfe_columns]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 73 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y132sZmlsZQ%3D%3D?line=0'>1</a> rfe_best_ix = np.argmin([score for _, score in rfe_results])
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y132sZmlsZQ%3D%3D?line=1'>2</a> rfe_columns, _ = rfe_results[rfe_best_ix]
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y132sZmlsZQ%3D%3D?line=3'>4</a> train_reduced_df = train_df[train_df.columns[rfe_columns]]
#
# NameError: name 'rfe_results' is not defined

# %% [markdown]
# ## Model selection
# First we get a baseline score for some of the avaliable classifiers in sklearn. The classifiers are imported from sklearn along with classification metrics for evaluation. The baseline scores are calculated using cross validation with 10 folds.

# %%
import warnings

warnings.filterwarnings("ignore")

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.dummy import DummyClassifier

from sklearn.model_selection import cross_validate

# %% [markdown]
# ###Training and evaluation on the training set

# %% [markdown]
# We create a function that trains and evaluates a model for each of the selected classifiers with default hyperparameters and run it on the feature-reduced training data set.

# %%
def evaluate_all_classifiers(train_df):
    classifiers = [
        LogisticRegression(),
        DecisionTreeClassifier(),
        RandomForestClassifier(),
        SVC(),
        KNeighborsClassifier(),
        GaussianNB(),
        GradientBoostingClassifier(),
        AdaBoostClassifier(),
        BaggingClassifier(),
        ExtraTreesClassifier(),
        MLPClassifier(),
        # use dummy classifier to get a baseline
        DummyClassifier(strategy="most_frequent"),
    ]

    all_results = []

    scoring = ["accuracy", "precision_macro", "recall_macro", "f1_macro"]

    for clf in classifiers:

        scores = cross_validate(
            clf,
            train_df,
            training_labels,
            scoring=scoring,
            cv=10,
            return_train_score=True,
        )

        print(
            f"Classifier: {clf.__class__.__name__}",
            "test accuracy",
            np.mean(scores["test_accuracy"]),
        )

        scores_mean = {a: np.mean(scores[a]) for a in scores.keys()}
        scores_mean["classifier"] = clf.__class__.__name__

        # save the evaluation results in a dataframe
        all_results.append(pd.DataFrame([scores_mean]))

    return pd.concat(all_results)


results = evaluate_all_classifiers(train_reduced_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3_jå.ipynb Cell 78 in <cell line: 48>()
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3_j%C3%A5.ipynb#Y140sZmlsZQ%3D%3D?line=42'>43</a>         all_results.append(pd.DataFrame([scores_mean]))
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3_j%C3%A5.ipynb#Y140sZmlsZQ%3D%3D?line=44'>45</a>     return pd.concat(all_results)
# ---> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3_j%C3%A5.ipynb#Y140sZmlsZQ%3D%3D?line=47'>48</a> results = evaluate_all_classifiers(train_reduced_df)
#
# NameError: name 'train_reduced_df' is not defined

# %% [markdown]
# ###Baseline scores

# %%
results.sort_values(by=["test_accuracy"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 80 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y142sZmlsZQ%3D%3D?line=0'>1</a> results.sort_values(by=["test_accuracy"])
#
# NameError: name 'results' is not defined

# %% [markdown]
# ###Conclusion
#
# The best performing classifier (using CV with 10 folds) is the `ExtraTreeClassifier` with an accuracy of approximately 0.93.

# %% [markdown]
# ##Fine-tuning models

# %% [markdown]
# Next step is to find optimal hyperparameters on the best performing classifier, `ExtraTreesClassifier`. We will do so by doing a CV Grid Search and will tune the following hyperparameters of the classifier:
#
# - n_estimators, controls the number of trees generated. Higher can give better performance, but may also increase likelihood of overfitting. The default value is 100 so we will probe around that value.
# - max_depth, the maximum depth of the tree. The default value is None, i.e. the max depth is not restricted so we first tested a wide range and concluded around 16 gives good results.

# %%
param_grid = {
    "n_estimators": np.arange(95, 105, 1),
    "max_depth": [15, 16, 17, 18],
    "bootstrap": [False, True],
}

cv = StratifiedKFold(n_splits=10)

searchCV = GridSearchCV(
    estimator=ExtraTreesClassifier(random_state=42),
    scoring="accuracy",
    cv=cv,
    param_grid=param_grid,
    verbose=True,
    n_jobs=4,
)

searchCV.fit(train_reduced_df, training_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 84 in <cell line: 18>()
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y146sZmlsZQ%3D%3D?line=6'>7</a> cv = StratifiedKFold(n_splits=10)
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y146sZmlsZQ%3D%3D?line=8'>9</a> searchCV = GridSearchCV(
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y146sZmlsZQ%3D%3D?line=9'>10</a>     estimator=ExtraTreesClassifier(random_state=42),
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y146sZmlsZQ%3D%3D?line=10'>11</a>     scoring="accuracy",
#    (...)
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y146sZmlsZQ%3D%3D?line=14'>15</a>     n_jobs=4,
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y146sZmlsZQ%3D%3D?line=15'>16</a> )
# ---> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y146sZmlsZQ%3D%3D?line=17'>18</a> searchCV.fit(train_reduced_df, training_labels)
#
# NameError: name 'train_reduced_df' is not defined

# %%
searchCV.best_params_, searchCV.best_score_

# %% [markdown]
# This gives the following best parameters to use in the evaluation on the test set:
#
#
# 1.   max_depth: 18
# 2.   n_estimators: 2

# %% [markdown]
# ##Evaluation on the test set

# %% [markdown]
# ###Choice of models to evaluate

# %% [markdown]
# We choose to evaluate the the models with the top five `test_accuracy` from the model selection section:
#
# 1.   `ExtraTreesClassifier` - 0.928
# 2.   `LogisticRegression` - 0.896
# 3.   `MLPClassifier` - 0.888
# 4.   `SVC` - 0.888
# 5.   `RandomForrestClassifier` - 0.885
#
# After these five models the accuracy starts to drop off a bit.

# %% [markdown]
# ###Evaluation

# %% [markdown]
# We fit the models to the preprocessed and feature-reduced training set, run predictions on the test set run through the same preprocessing and feature reduction and use `accuracy_score` from `sklearn.metrics` to get the final accuracy scores.

# %%
from sklearn.metrics import accuracy_score


def evaluate_models(
    training_features, training_labels, test_features, test_labels, classifiers
):
    prediction_scores = {}

    for index, clf in enumerate(classifiers):
        clf.fit(training_features, training_labels)
        prediction = clf.predict(test_features)
        prediction_scores[clf.__class__.__name__] = accuracy_score(
            test_labels, prediction
        )
    return prediction_scores


class ExtraTreesClassifier_Finetuned(ExtraTreesClassifier):
    def __init__(self):
        ExtraTreesClassifier.__init__(
            self, n_estimators=102, max_depth=18, random_state=42
        )


classifiers = [
    ExtraTreesClassifier(),
    ExtraTreesClassifier_Finetuned(),
    LogisticRegression(),
    MLPClassifier(),
    SVC(),
    RandomForestClassifier(),
]

prediction_scores = evaluate_models(
    train_reduced_df, training_labels, test_reduced_df, test_labels, classifiers
)
prediction_scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 92 in <cell line: 34>()
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=19'>20</a>         ExtraTreesClassifier.__init__(
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=20'>21</a>             self, n_estimators=102, max_depth=18, random_state=42
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=21'>22</a>         )
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=24'>25</a> classifiers = [
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=25'>26</a>     ExtraTreesClassifier(),
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=26'>27</a>     ExtraTreesClassifier_Finetuned(),
#    (...)
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=30'>31</a>     RandomForestClassifier(),
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=31'>32</a> ]
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=33'>34</a> prediction_scores = evaluate_models(
# ---> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=34'>35</a>     train_reduced_df, training_labels, test_reduced_df, test_labels, classifiers
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=35'>36</a> )
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y160sZmlsZQ%3D%3D?line=36'>37</a> prediction_scores
#
# NameError: name 'train_reduced_df' is not defined

# %% [markdown]
# Plot the performance (accuracy) of the classifiers on the train vs test dataset.

# %%
classifiers = [
    "ExtraTreesClassifier",
    "ExtraTreesClassifier_Finetuned",
    "LogisticRegression",
    "MLPClassifier",
    "SVC",
    "RandomForestClassifier",
]

N = len(classifiers)

train_results_df = pd.concat(
    [
        results,
        pd.DataFrame(
            [
                {
                    "classifier": "ExtraTreesClassifier_Finetuned",
                    "test_accuracy": searchCV.best_score_,
                }
            ]
        ),
    ]
)

train_results_df = train_results_df.set_index("classifier")

# Specify the values of blue bars (height)
blue_bar = train_results_df.loc[classifiers]["test_accuracy"].values
# Specify the values of orange bars (height)
orange_bar = [prediction_scores[c] for c in classifiers]

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(15, 8))

# Width of a bar
width = 0.3

# Plotting
plt.bar(ind, blue_bar, width, label="Train")
plt.bar(ind + width, orange_bar, width, label="Test")

plt.ylabel("Accuracy")
plt.title("Accuracy on train vs test sets")

plt.xticks(
    ind + width / 2,
    (
        "ExtraTreesClassifier",
        "ExtraTreesClassifier_Finetuned",
        "LogisticRegression",
        "MLPClassifier",
        "SVC",
        "RandomForestClassifier",
    ),
    rotation=90,
)


# Finding the best position for legends and putting it
plt.legend(loc="best")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# z:\Kurs\LTU\ai_pattern\task3\D7062E-projectgroup-10\Task3\task3 copy 2.ipynb Cell 94 in <cell line: 12>()
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=0'>1</a> classifiers = [
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=1'>2</a>     "ExtraTreesClassifier",
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=2'>3</a>     "ExtraTreesClassifier_Finetuned",
#    (...)
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=6'>7</a>     "RandomForestClassifier",
#       <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=7'>8</a> ]
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=9'>10</a> N = len(classifiers)
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=11'>12</a> train_results_df = pd.concat(
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=12'>13</a>     [
# ---> <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=13'>14</a>         results,
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=14'>15</a>         pd.DataFrame(
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=15'>16</a>             [
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=16'>17</a>                 {
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=17'>18</a>                     "classifier": "ExtraTreesClassifier_Finetuned",
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=18'>19</a>                     "test_accuracy": searchCV.best_score_,
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=19'>20</a>                 }
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=20'>21</a>             ]
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=21'>22</a>         ),
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=22'>23</a>     ]
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=23'>24</a> )
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=25'>26</a> train_results_df = train_results_df.set_index("classifier")
#      <a href='vscode-notebook-cell:/z%3A/Kurs/LTU/ai_pattern/task3/D7062E-projectgroup-10/Task3/task3%20copy%202.ipynb#Y162sZmlsZQ%3D%3D?line=27'>28</a> # Specify the values of blue bars (height)
#
# NameError: name 'results' is not defined

# %% [markdown]
# ### Conclusion

# %% [markdown]
# The prediction scores for the test set and the scores from the training were fairly close. The use of Cross Validation (and a high number of folds = 10) gave a good estimation of the performance on an unseen dataset.
#
# The dataset is very 'wide' with about 2 times the amount of rows/samples as there are features. We attempted two methods of feature/dimensionality reduction, RFE and PCA. RFE proved to work the best on the cross validated train data set.
#
# The best performing (in terms of accuracy) classifier on both train & test datasets was `ExtraTreesClassifier`, which seems to neither be over- or underfiting as the scores on both the training and test data are pretty close.
#
# The `LogisticRegression`, `MLPClassifier` and `SVC` classifiers all seems to be over- or underfitting slightly as their scores on the test set are a bit lower than on the training set.
#
# `RandomForestClassifier` is actually performing a bit better on the test set than on the training set.
#
# The tuned `ExtraTreesClassifier` does perform a bit better than the model with standard hyperparameters, it could perhaps be even better with some more tuning. On the other hand, more tuning could also risk overfitting it to the test set, which is why it's probably best to leave it as is.

# %% [markdown]
# # Task 3

# %%
# import pca
from sklearn.decomposition import PCA

# %%
# perform pca on train_df and plot the explained variance ratio
pca = PCA().fit(train_df)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.axhline(y=0.95, color='r', linestyle='-')
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# extract the number of components up to 0.95 explained variance
n_components = np.argmax(np.cumsum(pca.explained_variance_ratio_) >= 0.95) + 1
# print out the count of the number of components
print(n_components)

# extract the components ut to 0.95 explained variance
pca = PCA(n_components=n_components).fit(train_df)
# transform the train_df
train_reduced_df = pca.transform(train_df)
# transform the test_df
test_reduced_df = pca.transform(test_df)

# print out the shape of the train_reduced_df
print(train_reduced_df.shape)
print(train_df.shape)
# Out:
# 91
# (540, 91)
# (540, 240)

# %%
# evaluate the classifiers with and without PCA and save the results in a dataframe
results = evaluate_all_classifiers(train_df)
results_pca = evaluate_all_classifiers(train_reduced_df)

# merge the results of the classifiers with and without PCA
results = pd.concat([results, results_pca])
# add a column to the dataframe to indicate if PCA was used or not
results["pca"] = [False] * len(results_pca) + [True] * len(results_pca)
# set the index of the dataframe to the classifier name
results = results.set_index("classifier")

# print out the results
results
# Out:
# Classifier: LogisticRegression test accuracy 0.825925925925926
# Classifier: DecisionTreeClassifier test accuracy 0.5740740740740741
# Classifier: RandomForestClassifier test accuracy 0.861111111111111
# Classifier: SVC test accuracy 0.7203703703703703
# Classifier: KNeighborsClassifier test accuracy 0.45555555555555555
# Classifier: GaussianNB test accuracy 0.7
# Classifier: GradientBoostingClassifier test accuracy 0.6074074074074074
# Classifier: AdaBoostClassifier test accuracy 0.12407407407407404
# Classifier: BaggingClassifier test accuracy 0.7444444444444445
# Classifier: ExtraTreesClassifier test accuracy 0.8814814814814815
# Classifier: MLPClassifier test accuracy 0.7759259259259259
# Classifier: DummyClassifier test accuracy 0.0462962962962963
# Classifier: LogisticRegression test accuracy 0.7962962962962964
# Classifier: DecisionTreeClassifier test accuracy 0.2722222222222222
# Classifier: RandomForestClassifier test accuracy 0.6481481481481481
# Classifier: SVC test accuracy 0.711111111111111
# Classifier: KNeighborsClassifier test accuracy 0.45185185185185184
# Classifier: GaussianNB test accuracy 0.6129629629629629
# Classifier: GradientBoostingClassifier test accuracy 0.36111111111111105
# Classifier: AdaBoostClassifier test accuracy 0.08333333333333333
# Classifier: BaggingClassifier test accuracy 0.37037037037037035
# Classifier: ExtraTreesClassifier test accuracy 0.687037037037037
# Classifier: MLPClassifier test accuracy 0.7611111111111111
# Classifier: DummyClassifier test accuracy 0.0462962962962963
#                               fit_time  score_time  test_accuracy  \
# classifier
# LogisticRegression            9.581586    0.036401       0.825926
# DecisionTreeClassifier        0.526223    0.046066       0.574074
# RandomForestClassifier        2.720634    0.086400       0.861111
# SVC                           0.204899    0.048702       0.720370
# KNeighborsClassifier          0.014901    0.035100       0.455556
# GaussianNB                    0.021100    0.022902       0.700000
# GradientBoostingClassifier  114.044396    0.014288       0.607407
# AdaBoostClassifier            1.604454    0.030703       0.124074
# BaggingClassifier             1.038925    0.013901       0.744444
# ExtraTreesClassifier          0.413535    0.030303       0.881481
# MLPClassifier                 1.780815    0.015205       0.775926
# DummyClassifier               0.002200    0.006902       0.046296
# LogisticRegression            0.241081    0.008751       0.796296
# DecisionTreeClassifier        0.092520    0.006996       0.272222
# RandomForestClassifier        1.034204    0.035003       0.648148
# SVC                           0.083803    0.017202       0.711111
# KNeighborsClassifier          0.002800    0.014954       0.451852
# GaussianNB                    0.009601    0.011499       0.612963
# GradientBoostingClassifier   57.598042    0.014196       0.361111
# AdaBoostClassifier            0.994367    0.031401       0.083333
# BaggingClassifier             0.682392    0.009901       0.370370
# ExtraTreesClassifier          0.357531    0.025800       0.687037
# MLPClassifier                 2.236109    0.012204       0.761111
# DummyClassifier               0.001789    0.007100       0.046296
#
#                             train_accuracy  test_precision_macro  \
# classifier
# LogisticRegression                1.000000              0.814444
# DecisionTreeClassifier            1.000000              0.548119
# RandomForestClassifier            1.000000              0.843278
# SVC                               0.988683              0.706738
# KNeighborsClassifier              0.757819              0.435552
# GaussianNB                        0.938272              0.695810
# GradientBoostingClassifier        1.000000              0.637217
# AdaBoostClassifier                0.141564              0.045702
# BaggingClassifier                 0.997531              0.717111
# ExtraTreesClassifier              1.000000              0.881000
# MLPClassifier                     1.000000              0.758444
# DummyClassifier                   0.046296              0.001543
# LogisticRegression                1.000000              0.784500
# DecisionTreeClassifier            1.000000              0.243119
# RandomForestClassifier            1.000000              0.625333
# SVC                               0.982922              0.708460
# KNeighborsClassifier              0.759259              0.440963
# GaussianNB                        0.983128              0.604016
# GradientBoostingClassifier        1.000000              0.338956
# AdaBoostClassifier                0.098971              0.029952
# BaggingClassifier                 0.996502              0.331693
# ExtraTreesClassifier              1.000000              0.668333
# MLPClassifier                     1.000000              0.751667
# DummyClassifier                   0.046296              0.001543
#
#                             train_precision_macro  test_recall_macro  \
# classifier
# LogisticRegression                       1.000000           0.823333
# DecisionTreeClassifier                   1.000000           0.576111
# RandomForestClassifier                   1.000000           0.859444
# SVC                                      0.991239           0.712222
# KNeighborsClassifier                     0.812741           0.453333
# GaussianNB                               0.951422           0.713333
# GradientBoostingClassifier               1.000000           0.612222
# AdaBoostClassifier                       0.099994           0.111667
# BaggingClassifier                        0.997850           0.740556
# ExtraTreesClassifier                     1.000000           0.880556
# MLPClassifier                            1.000000           0.764444
# DummyClassifier                          0.001543           0.033333
# LogisticRegression                       1.000000           0.793333
# DecisionTreeClassifier                   1.000000           0.278333
# RandomForestClassifier                   1.000000           0.638889
# SVC                                      0.987134           0.702778
# KNeighborsClassifier                     0.811468           0.448889
# GaussianNB                               0.985230           0.603889
# GradientBoostingClassifier               1.000000           0.351667
# AdaBoostClassifier                       0.067021           0.073889
# BaggingClassifier                        0.996862           0.384444
# ExtraTreesClassifier                     1.000000           0.680000
# MLPClassifier                            1.000000           0.753333
# DummyClassifier                          0.001543           0.033333
#
#                             train_recall_macro  test_f1_macro  train_f1_macro  \
# classifier
# LogisticRegression                    1.000000       0.798143        1.000000
# DecisionTreeClassifier                1.000000       0.537857        1.000000
# RandomForestClassifier                1.000000       0.833532        1.000000
# SVC                                   0.987140       0.683939        0.988601
# KNeighborsClassifier                  0.751637       0.413778        0.758285
# GaussianNB                            0.944021       0.676169        0.940361
# GradientBoostingClassifier            1.000000       0.591612        1.000000
# AdaBoostClassifier                    0.126971       0.051421        0.068664
# BaggingClassifier                     0.997677       0.705413        0.997691
# ExtraTreesClassifier                  1.000000       0.863778        1.000000
# MLPClassifier                         1.000000       0.740214        1.000000
# DummyClassifier                       0.033333       0.002945        0.002950
# LogisticRegression                    1.000000       0.767817        1.000000
# DecisionTreeClassifier                1.000000       0.243402        1.000000
# RandomForestClassifier                1.000000       0.603444        1.000000
# SVC                                   0.980226       0.678923        0.982182
# KNeighborsClassifier                  0.754553       0.412089        0.761642
# GaussianNB                            0.983484       0.576013        0.983636
# GradientBoostingClassifier            1.000000       0.320865        1.000000
# AdaBoostClassifier                    0.085067       0.033809        0.046072
# BaggingClassifier                     0.996283       0.328979        0.996460
# ExtraTreesClassifier                  1.000000       0.647093        1.000000
# MLPClassifier                         1.000000       0.728238        1.000000
# DummyClassifier                       0.033333       0.002945        0.002950
#
#                               pca
# classifier
# LogisticRegression          False
# DecisionTreeClassifier      False
# RandomForestClassifier      False
# SVC                         False
# KNeighborsClassifier        False
# GaussianNB                  False
# GradientBoostingClassifier  False
# AdaBoostClassifier          False
# BaggingClassifier           False
# ExtraTreesClassifier        False
# MLPClassifier               False
# DummyClassifier             False
# LogisticRegression           True
# DecisionTreeClassifier       True
# RandomForestClassifier       True
# SVC                          True
# KNeighborsClassifier         True
# GaussianNB                   True
# GradientBoostingClassifier   True
# AdaBoostClassifier           True
# BaggingClassifier            True
# ExtraTreesClassifier         True
# MLPClassifier                True
# DummyClassifier              True

# %%
# bar plot of the results
sns.barplot(
    x="classifier",
    y="test_accuracy",
    hue="pca",
    data=results.reset_index(),
    palette="Set2",
)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# print out the difference in % between the results with and without PCA
results["pca_improvement"] = (
    results.loc[results["pca"] == True]["test_accuracy"]
    - results.loc[results["pca"] == False]["test_accuracy"]
) / results.loc[results["pca"] == False]["test_accuracy"] * 100

results.groupby(level=0)["pca_improvement"].first().sort_values()
# Out:
# classifier
# DecisionTreeClassifier       -53.376206
# BaggingClassifier            -45.728643
# GradientBoostingClassifier   -44.574780
# RandomForestClassifier       -25.158562
# ExtraTreesClassifier         -24.267782
# AdaBoostClassifier           -17.910448
# GaussianNB                   -12.137203
# LogisticRegression            -3.160271
# MLPClassifier                 -2.850356
# SVC                           -0.516796
# KNeighborsClassifier          -0.401606
# DummyClassifier                0.000000
# Name: pca_improvement, dtype: float64
